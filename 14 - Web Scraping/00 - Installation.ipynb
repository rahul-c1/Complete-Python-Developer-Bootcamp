# %% [markdown]
# # Preparation and Installation
#
# In order to web scrape you need to install the following packages.
#
# ```
# !conda install -y requests
# !conda install -y lxml
# !conda install -y bs4
# ```
#
# Or
#
# ```
# !pip install requests
# !pip install lxml
# !pip install bs4
# ```

# %%
# !conda install -y requests
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::holoviews==1.15.0=py39hecd8cb5_0
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/osx-64::imageio==2.19.3=py39hecd8cb5_0
#   - defaults/osx-64::scikit-learn==1.0.2=py39hae1ba45_1
#   - defaults/osx-64::bottleneck==1.3.5=py39h67323c0_0
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda-project==0.11.1=py39hecd8cb5_0
#   - defaults/osx-64::datashape==0.5.4=py39hecd8cb5_1
#   - defaults/osx-64::mkl_random==1.2.2=py39hb2f4e1b_0
#   - defaults/osx-64::numexpr==2.8.3=py39h2e5f0a9_0
#   - defaults/osx-64::imagecodecs==2021.8.26=py39h0f85e6e_1
#   - defaults/osx-64::h5py==3.7.0=py39h4a1dd59_0
#   - defaults/osx-64::pywavelets==1.3.0=py39hca72f7f_0
#   - defaults/osx-64::scikit-learn-intelex==2021.6.0=py39hecd8cb5_0
#   - defaults/osx-64::numpy==1.21.5=py39h2e5f0a9_3
#   - defaults/osx-64::jupyterlab==3.4.4=py39hecd8cb5_0
#   - defaults/osx-64::datashader==0.14.1=py39hecd8cb5_0
#   - defaults/osx-64::anaconda==2022.10=py39_0
#   - defaults/osx-64::matplotlib==3.5.2=py39hecd8cb5_0
#   - defaults/osx-64::hvplot==0.8.0=py39hecd8cb5_0
#   - defaults/noarch::nltk==3.7=pyhd3eb1b0_0
#   - defaults/osx-64::python-lsp-black==1.2.1=py39hecd8cb5_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_1
#   - defaults/osx-64::patsy==0.5.2=py39hecd8cb5_1
#   - defaults/osx-64::conda-build==3.22.0=py39hecd8cb5_0
#   - defaults/osx-64::sphinx==5.0.2=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.3.2=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_1
#   - defaults/osx-64::matplotlib-base==3.5.2=py39hfb0c5b7_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::statsmodels==0.13.2=py39hca72f7f_0
#   - defaults/osx-64::dask==2022.7.0=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-client==1.11.0=py39hecd8cb5_0
#   - defaults/osx-64::arrow-cpp==8.0.0=py39had1886b_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/osx-64::gensim==4.1.2=py39he9d5cce_0
#   - defaults/osx-64::numpydoc==1.4.0=py39hecd8cb5_0
#   - defaults/osx-64::pytables==3.6.1=py39h648f197_1
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/osx-64::pandas==1.4.4=py39he9d5cce_0
#   - defaults/osx-64::pyerfa==2.0.0=py39h9ed2024_0
#   - defaults/osx-64::distributed==2022.7.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_8
#   - defaults/osx-64::bokeh==2.4.3=py39hecd8cb5_0
#   - defaults/osx-64::mkl_fft==1.3.1=py39h4ab4a9b_0
#   - defaults/osx-64::conda-repo-cli==1.0.20=py39hecd8cb5_0
#   - defaults/osx-64::astropy==5.1=py39h67323c0_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::black==22.6.0=py39hecd8cb5_0
#   - defaults/osx-64::spyder==5.3.3=py39hecd8cb5_0
#   - defaults/osx-64::pyarrow==8.0.0=py39h2202ef3_0
#   - defaults/osx-64::panel==0.13.1=py39hecd8cb5_0
#   - defaults/osx-64::daal4py==2021.6.0=py39h01d92e1_1
#   - defaults/noarch::xarray==0.20.1=pyhd3eb1b0_1
# done
#
# ## Package Plan ##
#
#   environment location: /Users/rune/opt/anaconda3
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.10  |           py39_2          69 KB
#     anaconda-custom            |           py39_1           4 KB
#     ca-certificates-2023.01.10 |       hecd8cb5_0         121 KB
#     certifi-2022.12.7          |   py39hecd8cb5_0         151 KB
#     llvmlite-0.39.1            |   py39h8346a28_0         241 KB
#     numba-0.56.4               |   py39h07fba90_0         4.0 MB
#     openssl-1.1.1t             |       hca72f7f_0         3.3 MB
#     pytz-2022.7                |   py39hecd8cb5_0         210 KB
#     scikit-image-0.19.3        |   py39hcec6c5f_1         9.9 MB
#     ------------------------------------------------------------
#                                            Total:        18.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2022.10-py39_2
#   click              pkgs/main/osx-64::click-8.0.4-py39hecd8cb5_0
#   llvmlite           pkgs/main/osx-64::llvmlite-0.39.1-py39h8346a28_0
#   numba              pkgs/main/osx-64::numba-0.56.4-py39h07fba90_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.21.5-py39h3b1a694_3
#   pillow             pkgs/main/osx-64::pillow-9.2.0-py39hde71d04_1
#   pytz               pkgs/main/osx-64::pytz-2022.7-py39hecd8cb5_0
#   scikit-image       pkgs/main/osx-64::scikit-image-0.19.3-py39hcec6c5f_1
#   scipy              pkgs/main/osx-64::scipy-1.9.1-py39h3d31255_0
#   watchdog           pkgs/main/osx-64::watchdog-2.1.6-py39h999c104_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.07.19-hecd8cb5_0 --> 2023.01.10-hecd8cb5_0
#   certifi                          2022.9.24-py39hecd8cb5_0 --> 2022.12.7-py39hecd8cb5_0
#   openssl                                 1.1.1q-hca72f7f_0 --> 1.1.1t-hca72f7f_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2022.10-py39_0 --> custom-py39_1
#
#
#
# Downloading and Extracting Packages
# llvmlite-0.39.1      | 241 KB    |                                       |   0%
# certifi-2022.12.7    | 151 KB    |                                       |   0%
#
# pytz-2022.7          | 210 KB    |                                       |   0%
#
#
# numba-0.56.4         | 4.0 MB    |                                       |   0%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    |                                       |   0%
#
#
#
#
# _anaconda_depends-20 | 69 KB     |                                       |   0%
#
#
#
#
#
# openssl-1.1.1t       | 3.3 MB    |                                       |   0%
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    |                                       |   0%
#
#
#
#
#
#
#
# llvmlite-0.39.1      | 241 KB    | ##4                                   |   7%
# certifi-2022.12.7    | 151 KB    | ###9                                  |  11%
#
# pytz-2022.7          | 210 KB    | ##8                                   |   8%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    |                                       |   0%
#
#
# numba-0.56.4         | 4.0 MB    | 1                                     |   0%
#
#
#
#
# _anaconda_depends-20 | 69 KB     | ########5                             |  23%
#
#
#
#
#
# openssl-1.1.1t       | 3.3 MB    | 1                                     |   0%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    | ##9                                   |   8%
#
#
#
#
#
#
#
# anaconda-custom      | 4 KB      | ##################################### | 100%
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ####8                                 |  13%
# certifi-2022.12.7    | 151 KB    | ##################################### | 100%
# certifi-2022.12.7    | 151 KB    | ##################################### | 100%
#
#
# llvmlite-0.39.1      | 241 KB    | ##################################### | 100%
#
#
#
#
#
# openssl-1.1.1t       | 3.3 MB    | #########6                            |  26%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    | ######2                               |  17%
#
#
# numba-0.56.4         | 4.0 MB    | ###########8                          |  32%
#
# pytz-2022.7          | 210 KB    | ##################################### | 100%
#
# pytz-2022.7          | 210 KB    | ##################################### | 100%
#
#
#
#
# _anaconda_depends-20 | 69 KB     | ##################################### | 100%
#
#
#
#
# _anaconda_depends-20 | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# anaconda-custom      | 4 KB      | ##################################### | 100%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    | ##############4                       |  39%
#
#
#
#
#
# openssl-1.1.1t       | 3.3 MB    | #################################5    |  91%
# numba-0.56.4         | 4.0 MB    | #############################5        |  80%
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ##################################### | 100%
#
#
#
#
#
#
# ca-certificates-2023 | 121 KB    | ##################################### | 100%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    | ##################9                   |  51%
#
#
#
#
#
# openssl-1.1.1t       | 3.3 MB    | ##################################### | 100%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    | ######################6               |  61%
#
#
# numba-0.56.4         | 4.0 MB    | ##################################### | 100%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    | ##########################1           |  71%
#
#
#
# scikit-image-0.19.3  | 9.9 MB    | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y lxml
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install -y bs4
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
